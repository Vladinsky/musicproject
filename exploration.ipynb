# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.ingestion import load_and_clean_data

# %%
file_path = 'data/mxmh_survey_results.csv'
df = load_and_clean_data(file_path)

# %%
# Set Palette colori
color_1 = '#44355B'
color_2 = '#221E22'
color_3 = '#C42021'
color_4 = '#EE5622'
color_5 = '#ECA72C'

palette = 'magma'

# %%
# What is the correlation between the numeric values?
corr_matrix = df.select_dtypes(include=["number"]).corr()

plt.figure(figsize=(10, 8))
sns.heatmap(
    corr_matrix,
    cmap=palette,
    annot=True,
    fmt=".2f",
    linewidths=5,
    linecolor="white",
    vmin=-1,
    vmax=1,
    cbar_kws={"shrink": 0.8, "orientation": "vertical"},  # Personalizza la barra dei colori
    square=True
)
plt.title("Correlation between numeric values", fontsize=20)
plt.show()

# %%
# Scatterplot BPM-Depression
plt.figure(figsize=(10, 8))
sns.scatterplot(
                x='BPM',
                  y='Depression',
                    data=df,
                      hue
    ='Depression', palette=palette
)
plt.title("Scatterplot BPM-Depression", fontsize=20)
plt.show()
